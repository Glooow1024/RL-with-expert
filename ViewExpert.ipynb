# %%
# 测试 expert.py 中的 Expert
# 查看保存的 expert 数据
# liyi, 2019/6/27

from expert import Expert

expert_dir = './expert_data/HalfCheetah-v2'
data = Expert(expert_dir)
print(data.value())
# Out:
# /home/liyi/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Expert dataset initialized!
# length  1000000
# states  torch.Size([1000, 1000, 17])
# episode  59001 tensor([-0.0086])
# episode  59002 tensor([-0.0022])
# episode  59003 tensor([0.0034])
# episode  59004 tensor([0.0002])
# episode  59005 tensor([-0.0030])
# episode  59006 tensor([-0.0097])
# episode  59007 tensor([-0.0016])
# episode  59008 tensor([0.0049])
# episode  59009 tensor([0.0048])
# episode  59010 tensor([0.0010])
# episode  59011 tensor([-0.0085])
# episode  59012 tensor([-0.0069])
# episode  59013 tensor([0.0091])
# episode  59014 tensor([0.0088])
# episode  59015 tensor([-0.0028])
# episode  59016 tensor([-0.0041])
# episode  59017 tensor([0.0020])
# ...

# %%
data.__getitem__(500000)
# Out:
# (tensor([ 1.8662, -0.8942, -0.1869, -0.3047,  0.0350,  0.0314,  0.2415, -0.0224,
#          -0.0376,  0.0464, -0.1102, -0.0132,  0.0186, -0.0056,  0.0031,  0.0122,
#           0.0115]),
#  tensor([-0.2128, -0.2207,  0.0180, -0.8264, -0.1154, -1.3213]),
#  tensor([-0.0048]),
#  tensor(0.))
